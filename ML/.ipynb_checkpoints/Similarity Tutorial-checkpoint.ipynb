# %%
import Similarity as sim

# %%
similarity = sim.FinalSimilarity('JournalDataUse.csv','TweetDataUse.csv')

# %%
similarity.tweetData['Topik']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 similarity.tweetData['Topik']
#
# NameError: name 'similarity' is not defined

# %%
similarity.journalData.head()
# Out:
#    Unnamed: 0                                              Judul  \
# 0           0    Aktivisme dan Kesukarelawanan dalam Media So...
# 1           1    Silent Political Apathy in Urban Society: Th...
# 2           2    Karst: Ditambang atau Dilestarikan, Konflik ...
# 3           3    Jalan Panjang Penyelesaian Konflik Kasus Lum...
# 4           4    Masyarakat Adat versus Korporasi: Konflik So...
#
#                                              Penulis  \
# 0       Ramma Wisnu Dewantara, Derajat S. Widhyharto
# 1  Derajad Sulistyo Widhyharto, Desi Rahmawati, N...
# 2                                          - Suharko
# 3                                        Anis Farida
# 4                                    Suharko Suharko
#
#                                             PDF_Link  \
# 0  https://jurnal.ugm.ac.id/jsp/article/view/1085...
# 1  https://jurnal.ugm.ac.id/jsp/article/view/5172...
# 2  https://jurnal.ugm.ac.id/jsp/article/view/1088...
# ...

# %%
similarity.getSimilarity(2)

# %%
similarity.journalData.head()
# Out:
#    Unnamed: 0                                              Judul  \
# 0           0    Aktivisme dan Kesukarelawanan dalam Media So...
# 1           1    Silent Political Apathy in Urban Society: Th...
# 2           2    Karst: Ditambang atau Dilestarikan, Konflik ...
# 3           3    Jalan Panjang Penyelesaian Konflik Kasus Lum...
# 4           4    Masyarakat Adat versus Korporasi: Konflik So...
#
#                                              Penulis  \
# 0       Ramma Wisnu Dewantara, Derajat S. Widhyharto
# 1  Derajad Sulistyo Widhyharto, Desi Rahmawati, N...
# 2                                          - Suharko
# 3                                        Anis Farida
# 4                                    Suharko Suharko
#
#                                             PDF_Link  \
# 0  https://jurnal.ugm.ac.id/jsp/article/view/1085...
# 1  https://jurnal.ugm.ac.id/jsp/article/view/5172...
# 2  https://jurnal.ugm.ac.id/jsp/article/view/1088...
# ...
